# %% [markdown]
# # Imports and initialization of general parameters
# ***

# %%
from config.info import AGES, RACES, GENDERS, COMBS_BASELINE
from visualization.subgroup_distribution import plot_dist
from dataprocess.dataloader import load_data
from dataprocess.dataclass import Data
from config.get_args import get_args
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
import argparse
import pandas as pd


# Auto reload part
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the desired data set
# ***

# %%
ref = pd.read_pickle('data/info.pkl')
ref[:100]
# Out:
#                      task        cancer label age_ race_ gender_  \
# 0   cancer_classification  coad_read_FS     0    7     1       1
# 1   cancer_classification  coad_read_FS     0    6     1       0
# 2   cancer_classification  coad_read_FS     0    7     1       1
# 3   cancer_classification  coad_read_FS     0    7     1       1
# 4   cancer_classification  coad_read_FS     0    6     1       0
# ..                    ...           ...   ...  ...   ...     ...
# 95  cancer_classification  coad_read_FS     0    4     3       0
# 96  cancer_classification  coad_read_FS     0    5     1       0
# 97  cancer_classification  coad_read_FS     0    5     1       0
# 98  cancer_classification  coad_read_FS     0    5     1       1
# 99  cancer_classification  coad_read_FS     0    5     1       1
#
#             subj siteID age_str race_str gender_str
# 0   TCGA-DM-A28A     DM       7    WHITE       MALE
# 1   TCGA-DM-A282     DM       6    WHITE     FEMALE
# 2   TCGA-CM-5348     CM       7    WHITE       MALE
# 3   TCGA-CM-5348     CM       7    WHITE       MALE
# 4   TCGA-CM-6678     CM       6    WHITE     FEMALE
# ..           ...    ...     ...      ...        ...
# 95  TCGA-A6-2685     A6       4    BLACK     FEMALE
# 96  TCGA-D5-6898     D5       5    WHITE     FEMALE
# 97  TCGA-D5-6898     D5       5    WHITE     FEMALE
# 98  TCGA-CM-6679     CM       5    WHITE       MALE
# 99  TCGA-CM-6679     CM       5    WHITE       MALE
#
# [100 rows x 11 columns]

# %%
# Modifications of the refs 
ref['age_str'] = ref.age_.astype(str)
ref['race_str'] = ref.apply(lambda row : RACES['str'][row['race_']], axis = 1)
ref['gender_str'] = ref.apply(lambda row : GENDERS['str'][row['gender_']], axis = 1)
ref.reset_index(inplace=True, drop = True)

# %%
fig = px.histogram(ref, x = "cancer", color = 'task', 
                   text_auto = True, 
                   color_discrete_sequence = ['rgb(50, 100, 170)', 'rgb(21, 21, 45)'],
                   template = 'none',
                   width = 800, 
                   height = 400)
fig.update_xaxes(tickangle = 40)
fig.write_image("images/eda_1.eps")
fig.show()
# Out:
# <div>                            <div id="1b6c9593-7f67-4d78-9242-e984114f9c63" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b6c9593-7f67-4d78-9242-e984114f9c63")) {                    Plotly.newPlot(                        "1b6c9593-7f67-4d78-9242-e984114f9c63",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"task=cancer_classification<br>cancer=%{x}<br>count=%{y}<extra></extra>","legendgroup":"cancer_classification","marker":{"color":"rgb(50, 100, 170)","pattern":{"shape":""}},"name":"cancer_classification","offsetgroup":"cancer_classification","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS","coad_read_FS ...

# %% [markdown]
# # Protected attributes
# ***

# %%
# Reduce the refs
# c1 = 'kirc_kirp_PM'
# c2 = 'lusc'
c1 = 'coad_read_FS'
c2 = 'coad_read_PM'
ref1 = ref[ref.cancer == c1].sort_values(by = ['gender_str'])
ref2 = ref[ref.cancer == c2]#.sort_values(by = ['gender_str'])

# %%
# Initialization of the plot
fig = make_subplots(rows = 2, cols = 3,
                    subplot_titles=('',  f'Cancer classification for {c1}', '', '', f'Tumor detection for {c2}', ''))

# Traces
trace1_1 = px.histogram(ref1, x = 'age_', color = 'gender_',
                        color_discrete_sequence = ['rgb(180, 40, 40)', 'rgb(40, 40, 140)']).update_traces(showlegend = False).update_xaxes()
trace1_2 = px.histogram(ref1, x = 'race_str', color = 'gender_str',
                        color_discrete_sequence = ['rgb(180, 40, 40)', 'rgb(40, 40, 140)']).update_traces(showlegend = False)
trace1_3 = px.histogram(ref1, x='gender_str', color='gender_str',
                        color_discrete_sequence = ['rgb(180, 40, 40)', 'rgb(40, 40, 140)'])
trace2_1 = px.histogram(ref2, x = 'age_str', color = 'gender_str',
                        color_discrete_sequence = ['rgb(180, 40, 40)', 'rgb(40, 40, 140)']).update_traces(showlegend = False)
trace2_2 = px.histogram(ref2, x = 'race_str', color = 'gender_str',
                        color_discrete_sequence = ['rgb(180, 40, 40)', 'rgb(40, 40, 140)']).update_traces(showlegend = False)
trace2_3 = px.histogram(ref2, x='gender_str', color='gender_str',
                        color_discrete_sequence = ['rgb(180, 40, 40)', 'rgb(40, 40, 140)']).update_traces(showlegend = False)

# Update the figure
for t in range(len(trace1_1['data'])): fig.add_trace(trace1_1['data'][t], row = 1, col = 1)
for t in range(len(trace1_2['data'])): fig.add_trace(trace1_2['data'][t], row = 1, col = 2)
for t in range(len(trace1_3['data'])): fig.add_trace(trace1_3['data'][t], row = 1, col = 3)
for t in range(len(trace2_1['data'])): fig.add_trace(trace2_1['data'][t], row = 2, col = 1)
for t in range(len(trace2_2['data'])): fig.add_trace(trace2_2['data'][t], row = 2, col = 2)
for t in range(len(trace2_3['data'])): fig.add_trace(trace2_3['data'][t], row = 2, col = 3)
fig['layout']['xaxis']['title']='age'
fig['layout']['yaxis']['title']='count'
fig['layout']['xaxis2']['title']='race'
fig['layout']['xaxis3']['title']='gender'
fig['layout']['xaxis4']['title']='age'
fig['layout']['yaxis4']['title']='count'
fig['layout']['xaxis5']['title']='race'
fig['layout']['xaxis6']['title']='gender'
fig.update_layout(height = 700, width = 1100, template = 'none',
                  xaxis1 = dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]),
                  xaxis4 = dict(tickvals=[4, 5, 6, 7, 8]))
fig.update_layout(barmode = 'group', bargap = 0.3, bargroupgap = 0.1)
fig.update_coloraxes(showscale=False)
fig.write_image("images/eda_2.eps")
fig.show()
# Out:
# <div>                            <div id="2d4b2aa9-b520-49d0-97ee-f9855c85bb16" class="plotly-graph-div" style="height:700px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d4b2aa9-b520-49d0-97ee-f9855c85bb16")) {                    Plotly.newPlot(                        "2d4b2aa9-b520-49d0-97ee-f9855c85bb16",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"gender_=0<br>age_=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"rgb(180, 40, 40)","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":false,"x":["6","7","4","6","6","4","4","5","5","4","4","9","9","7","7","7","7","7","7","6","6","3","4","4","4","4","4","6","6","6","7","6","6","6","3","3","5","4","5","5","6","7","7","8","7","7","7","7","5","5","6","6","3","6","4","4","6","6","7","6","6","7","6","4","3","5","8","6","6","5","5","4","4","6","8","8","4","4","7","7","4","4","5","8","8","7","7","7","6","6","4","4","4","7","4","4","6","4","7","5","7","7","6","6","5","5","7","6","5","5","7","8","9","9","8","6","5","7","5","3","6","6","4","4","4","5","5","8","3","7","6","7","5","6","7","7","7","7","7","7","8","4","7","7","5","6","6","7","5","5","9","4","8","5","7","5","5","5","7","6","7","4","7","7","5","5","4","6","8","8","5","5","7","7","5","8","4","4","5","5","7","5","5","5","5","7","5","4","5","4","5","7","8","5","4","7","5","5","5","5","5","7","7","5","7","7","7","7","5","5","6","7","5","5","4","4","6","8","6","7","7","7","7","7","7","7","5","8","7","7","8","4","7","3","8","7","8","3","5","5","7","8","8","4","6","6","5","7","7","7","5","7","6","4","4","5","7","5","5","6","6","8","8","7","8","8","7","8","4","7","7","7","8","7","7","5","7","7","5","7","5","5","7","8","5","7","6","3","6","3","8","7","5","5","4","7","6","5","6"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"gender_=1<br>age_=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"rgb(40, 40, 140)","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":false,"x":["5","9","9","7","6","6","7","7","5","7","7","7","7","7","5","5","5","4","7","5","7","4","5","4","7","5","5","5","6","7","5","6","6","7","6","6","6","7","4","4","5","5","6","6","7","4","5","7","5","6","6","4","6","7","4","6","4","6","5","6","5","5","5","5","5","7","5","5","7","5","6","6","3","3","7","7","5","6","6","6","4","7","7","7","7","7","6","6","5","5","5","5","5","6","5","7","7","4","6","6","7","4","4","6","6","4","4","4","5","7","5","7","7","6","5","5","5","5","7","4","7","6","5","7","7","6","6","6","6","4","4","5","5","7","7","6","6","6","6","7","7","3","3","7","7","4","7","5","5","8","3","8","8","8","6","6","7","7","7","6","6","6","8","5","7","7","4","4","6","6","6","6","7","5","3","5","6","7","7","6","6","6","6","5","8","8","8","8","8","8","7","7","8","8","8","8","4","4","7","7","7","6","7","7","7","7","8","8","7","7","6","6","6","5","5","6","3","3","5","5","6","6","7","7","3","3","7","7","5","6","6","8","5","5","7","7","4","4","6","6","9","9","7","8","8","7","7","7","7","5","5","3","8","8","6","8","6","8","6","6","6","8","6","6","6","6","6","6","7","7","6","6","5","7","7","6","6","8","8","7","8","5","6","6","4","5","5","7","7","6","6","8","8","6","6","8","8","8","8","8","8","6","6","5","5","7","4","4","4","4","4","4","4","6","6","6","8","8","7","7","6","5","6","6","6","5","8","6","7","7","7","4","4","6","6","6","5","6"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"gender_str=FEMALE<br>race_str=%{x}<br>count=%{y}<extra></extra>","legendgroup":"FEMALE","marker":{"color":"rgb(180, 40, 40)","pattern":{"shape":""}},"name":"FEMALE","offsetgroup":"FEMALE","orientation":"v","showlegend":false,"x":["WHITE","WHITE","WHITE ...

# %% [markdown]
# ***

# %%
# Build the pivot matrices
# Init
p1 = ref1.copy()
p1['a'] = 1
p2 = ref2.copy()
p2['a'] = 1

# Pivot for female
p1_f = pd.pivot_table(p1[p1.gender_str == 'FEMALE'][['age_str', 'race_str', 'a']], index= ['age_str'], columns = ['race_str'], aggfunc = 'count' )
p1_f = p1_f['a']
p2_f = pd.pivot_table(p2[p2.gender_str == 'FEMALE'][['age_str', 'race_str', 'a']], index= ['age_str'], columns = ['race_str'], aggfunc = 'count' )
p2_f = p2_f['a']

# Pivot for male
p1_m = pd.pivot_table(p1[p1.gender_str == 'MALE'][['age_str', 'race_str', 'a']], index= ['age_str'], columns = ['race_str'], aggfunc = 'count' )
p1_m = p1_m['a']
p2_m = pd.pivot_table(p2[p2.gender_str == 'MALE'][['age_str', 'race_str', 'a']], index= ['age_str'], columns = ['race_str'], aggfunc = 'count' )
p2_m = p2_m['a']

# %%
# Build the subplot
fig = make_subplots(2, 2, horizontal_spacing = 0.14,
                    subplot_titles=(f'Female patients ({c1})', f'Male patients ({c1})', f'Female patients ({c2})', f'Male patients ({c2})'))

# Add the heatmaps
fig.add_trace(go.Heatmap(x = p1_f.columns, y = p1_f.index, z = p1_f, coloraxis = 'coloraxis', texttemplate = '%{z}'), 1, 1)
fig.add_trace(go.Heatmap(x = p1_m.columns, y = p1_m.index, z = p1_m, coloraxis = 'coloraxis2', texttemplate = '%{z}'), 1, 2)
fig.add_trace(go.Heatmap(x = p2_f.columns, y = p2_f.index, z = p2_f, coloraxis = 'coloraxis3', texttemplate = '%{z}'), 2, 1)
fig.add_trace(go.Heatmap(x = p2_m.columns, y = p2_m.index, z = p2_m, coloraxis = 'coloraxis4', texttemplate = '%{z}'), 2, 2)

# Update the figures
fig.update_layout(height = 600, width = 1000,
                  template = 'none',
                  yaxis = {"title": 'age'},
                  yaxis2 = {"title": 'age'},
                  yaxis3 = {"title": 'age'},
                  yaxis4 = {"title": 'age'},
                  xaxis = {"title": 'race'},
                  xaxis2 = {"title": 'race'},
                  xaxis3 = {"title": 'race'},
                  xaxis4 = {"title": 'race'},
                  coloraxis = dict(colorscale='matter_r', colorbar_x=0.43, colorbar_y=0.8, colorbar_len = 0.5, colorbar_thickness=23),
                  coloraxis2 = dict(colorscale='ice', colorbar_x=1, colorbar_y=0.8, colorbar_len = 0.5, colorbar_thickness=23),
                  coloraxis3 = dict(colorscale='matter_r', colorbar_x=0.43, colorbar_y=0.2, colorbar_len = 0.5, colorbar_thickness=23),
                  coloraxis4 = dict(colorscale='ice', colorbar_x=1, colorbar_y=0.2, colorbar_len = 0.5, colorbar_thickness=23)) #deep_r
fig.update_layout(yaxis=dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]),
                  yaxis2=dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]),
                  yaxis3=dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]),
                  yaxis4=dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]))
fig.write_image("images/eda_3.eps")
fig.show()
# Out:
# <div>                            <div id="856fa006-b8ac-4cff-967d-242b502ddd79" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("856fa006-b8ac-4cff-967d-242b502ddd79")) {                    Plotly.newPlot(                        "856fa006-b8ac-4cff-967d-242b502ddd79",                        [{"coloraxis":"coloraxis","texttemplate":"%{z}","x":["ASIAN","BLACK","WHITE"],"y":["3","4","5","6","7","8","9"],"z":[[null,1.0,10.0],[2.0,8.0,36.0],[4.0,10.0,55.0],[null,11.0,39.0],[null,7.0,81.0],[null,5.0,25.0],[null,1.0,4.0]],"type":"heatmap","xaxis":"x","yaxis":"y"},{"coloraxis":"coloraxis2","texttemplate":"%{z}","x":["AMERICAN INDIAN","ASIAN","BLACK","WHITE"],"y":["3","4","5","6","7","8","9"],"z":[[null,null,4.0,7.0],[null,4.0,4.0,28.0],[null,6.0,13.0,45.0],[2.0,3.0,12.0,81.0],[null,1.0,6.0,79.0],[null,null,3.0,36.0],[null,null,2.0,2.0]],"type":"heatmap","xaxis":"x2","yaxis":"y2"},{"coloraxis":"coloraxis3","texttemplate":"%{z}","x":["ASIAN","BLACK","WHITE"],"y":["3","4","5","6","7","8","9"],"z":[[null,1.0,5.0],[1.0,7.0,18.0],[2.0,7.0,30.0],[null,11.0,25.0],[null,7.0,49.0],[null,3.0,13.0],[null,1.0,2.0]],"type":"heatmap","xaxis":"x3","yaxis":"y3"},{"coloraxis":"coloraxis4","texttemplate":"%{z}","x":["AMERICAN INDIAN","ASIAN","BLACK","WHITE"],"y":["3","4","5","6","7","8","9"],"z":[[null,null,2.0,3.0],[null,2.0,3.0,16.0],[null,3.0,10.0,23.0],[1.0,2.0,9.0,47.0],[null,1.0,6.0,48.0],[null,null,5.0,22.0],[null,null,1.0,1.0]],"type":"heatmap","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"xaxis":{"anchor":"y","domain":[0.0,0.43],"title":{"text":"race"}},"yaxis":{"anchor":"x","domain":[0.625,1.0],"title":{"text":"age"},"tickvals":[2,3,4,5,6,7,8,9]},"xaxis2":{"anchor":"y2","domain":[0.5700000000000001,1.0],"title":{"text":"race"}},"yaxis2":{"anchor":"x2","domain":[0.625,1.0],"title":{"text":"age"},"tickvals":[2,3,4,5,6,7,8,9]},"xaxis3":{"anchor":"y3","domain":[0.0,0.43],"title":{"text":"race"}},"yaxis3":{"anchor":"x3","domain":[0.0,0.375],"title":{"text":"age"},"tickvals":[2,3,4,5,6,7,8,9]},"xaxis4":{"anchor":"y4","domain":[0.5700000000000001,1.0],"title":{"text":"race"}},"yaxis4":{"anchor":"x4","domain":[0.0,0.375],"title":{"text":"age"},"tickvals":[2,3,4,5,6,7,8,9]},"annotations":[{"font":{"size":16},"showarrow":false,"text":"Female patients (coad_read_FS)","x":0.215,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Male patients (coad_read_FS)","x":0.785,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Female patients (coad_read_PM)","x":0.215,"xanchor":"center","xref":"paper","y":0.375,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Male patients (coad_read_PM)","x":0.785,"xanchor":"center","xref":"paper","y":0.375,"yanchor":"bottom","yref":"paper"}],"coloraxis":{"colorbar":{"x":0.43,"y":0.8,"len":0.5,"thickness":23},"colorscale":[[0.0,"rgb(47, 15, 61)"],[0.09090909090909091,"rgb(76, 21, 80)"],[0.18181818181818182,"rgb(107, 24, 93)"],[0.2727272727272727,"rgb(138, 29, 99)"],[0.36363636363636365,"rgb(168, 40, 96)"],[0.45454545454545453,"rgb(195, 56, 90)"],[0.5454545454545454,"rgb(216, 80, 83)"],[0.6363636363636364,"rgb(231, 109, 84)"],[0.7272727272727273,"rgb(240, 142, 98)"],[0.8181818181818182,"rgb(246, 173, 119)"],[0.9090909090909091,"rgb(250, 205, 145)"],[1.0,"rgb(253, 237, 176)"]]},"coloraxis2":{"colorscale":[[0.0,"rgb(3, 5, 18)"],[0.09090909090909091,"rgb(25, 25, 51)"],[0.18181818181818182,"rgb(44, 42, 87)"],[0.2727272727272727,"rgb(58, 60, 125)"],[0.36363636363636365,"rgb(62, 83, 160)"],[0.45454545454545453,"rgb(62, 109, 178)"],[0.5454545454545454,"rgb(72, 134, 187)" ...
#
# var gd = document.getElementById('856fa006-b8ac-4cff-967d-242b502ddd79');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# Build the pivot matrices
# Init
p1 = ref1.copy()
p1['a'] = 1
p2 = ref2.copy()
p2['a'] = 1

# Pivot for female
p1_f = pd.pivot_table(p1[p1.label == 0][['age_str', 'race_str', 'a']], index= ['age_str'], columns = ['race_str'], aggfunc = 'count' )
p1_f = p1_f['a']
p2_f = pd.pivot_table(p2[p2.label == 0][['age_str', 'race_str', 'a']], index= ['age_str'], columns = ['race_str'], aggfunc = 'count' )
p2_f = p2_f['a']

# Pivot for male
p1_m = pd.pivot_table(p1[p1.label == 1][['age_str', 'race_str', 'a']], index= ['age_str'], columns = ['race_str'], aggfunc = 'count' )
p1_m = p1_m['a']
p2_m = pd.pivot_table(p2[p2.label == 1][['age_str', 'race_str', 'a']], index= ['age_str'], columns = ['race_str'], aggfunc = 'count' )
p2_m = p2_m['a']

# %%
# Build the subplot
fig = make_subplots(2, 2, horizontal_spacing = 0.14,
                    subplot_titles=(f'Female patients ({c1})', f'Male patients ({c1})', f'Female patients ({c2})', f'Male patients ({c2})'))

# Add the heatmaps
fig.add_trace(go.Heatmap(x = p1_f.columns, y = p1_f.index, z = p1_f, coloraxis = 'coloraxis', texttemplate = '%{z}'), 1, 1)
fig.add_trace(go.Heatmap(x = p1_m.columns, y = p1_m.index, z = p1_m, coloraxis = 'coloraxis2', texttemplate = '%{z}'), 1, 2)
fig.add_trace(go.Heatmap(x = p2_f.columns, y = p2_f.index, z = p2_f, coloraxis = 'coloraxis3', texttemplate = '%{z}'), 2, 1)
fig.add_trace(go.Heatmap(x = p2_m.columns, y = p2_m.index, z = p2_m, coloraxis = 'coloraxis4', texttemplate = '%{z}'), 2, 2)

# Update the figures
fig.update_layout(height = 600, width = 1000,
                  template = 'none',
                  yaxis = {"title": 'age'},
                  yaxis2 = {"title": 'age'},
                  yaxis3 = {"title": 'age'},
                  yaxis4 = {"title": 'age'},
                  xaxis = {"title": 'race'},
                  xaxis2 = {"title": 'race'},
                  xaxis3 = {"title": 'race'},
                  xaxis4 = {"title": 'race'},
                  coloraxis = dict(colorscale='matter_r', colorbar_x=0.43, colorbar_y=0.8, colorbar_len = 0.5, colorbar_thickness=23),
                  coloraxis2 = dict(colorscale='deep_r', colorbar_x=1, colorbar_y=0.8, colorbar_len = 0.5, colorbar_thickness=23),
                  coloraxis3 = dict(colorscale='matter_r', colorbar_x=0.43, colorbar_y=0.2, colorbar_len = 0.5, colorbar_thickness=23),
                  coloraxis4 = dict(colorscale='deep_r', colorbar_x=1, colorbar_y=0.2, colorbar_len = 0.5, colorbar_thickness=23))
fig.update_layout(yaxis=dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]),
                  yaxis2=dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]),
                  yaxis3=dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]),
                  yaxis4=dict(tickvals=[2, 3, 4, 5, 6, 7, 8, 9]))
fig.write_image("images/eda_3.eps")
fig.show()
# Out:
# <div>                            <div id="3b11e899-49ef-478b-bac8-809c3ceda4ff" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b11e899-49ef-478b-bac8-809c3ceda4ff")) {                    Plotly.newPlot(                        "3b11e899-49ef-478b-bac8-809c3ceda4ff",                        [{"coloraxis":"coloraxis","texttemplate":"%{z}","x":["AMERICAN INDIAN","ASIAN","BLACK","WHITE"],"y":["3","4","5","6","7","8","9"],"z":[[null,null,5.0,11.0],[null,6.0,8.0,42.0],[null,8.0,22.0,63.0],[2.0,3.0,19.0,88.0],[null,1.0,13.0,111.0],[null,null,8.0,59.0],[null,null,3.0,4.0]],"type":"heatmap","xaxis":"x","yaxis":"y"},{"coloraxis":"coloraxis2","texttemplate":"%{z}","x":["ASIAN","BLACK","WHITE"],"y":["3","4","5","6","7","8","9"],"z":[[null,null,6.0],[null,4.0,22.0],[2.0,1.0,37.0],[null,4.0,32.0],[null,null,49.0],[null,null,2.0],[null,null,2.0]],"type":"heatmap","xaxis":"x2","yaxis":"y2"},{"coloraxis":"coloraxis3","texttemplate":"%{z}","x":["AMERICAN INDIAN","ASIAN","BLACK","WHITE"],"y":["3","4","5","6","7","8","9"],"z":[[null,null,3.0,5.0],[null,3.0,7.0,23.0],[null,4.0,16.0,34.0],[1.0,2.0,18.0,56.0],[null,1.0,13.0,71.0],[null,null,8.0,34.0],[null,null,2.0,2.0]],"type":"heatmap","xaxis":"x3","yaxis":"y3"},{"coloraxis":"coloraxis4","texttemplate":"%{z}","x":["ASIAN","BLACK","WHITE"],"y":["3","4","5","6","7","8","9"],"z":[[null,null,3.0],[null,3.0,11.0],[1.0,1.0,19.0],[null,2.0,16.0],[null,null,26.0],[null,null,1.0],[null,null,1.0]],"type":"heatmap","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"xaxis":{"anchor":"y","domain":[0.0,0.43],"title":{"text":"race"}},"yaxis":{"anchor":"x","domain":[0.625,1.0],"title":{"text":"age"},"tickvals":[2,3,4,5,6,7,8,9]},"xaxis2":{"anchor":"y2","domain":[0.5700000000000001,1.0],"title":{"text":"race"}},"yaxis2":{"anchor":"x2","domain":[0.625,1.0],"title":{"text":"age"},"tickvals":[2,3,4,5,6,7,8,9]},"xaxis3":{"anchor":"y3","domain":[0.0,0.43],"title":{"text":"race"}},"yaxis3":{"anchor":"x3","domain":[0.0,0.375],"title":{"text":"age"},"tickvals":[2,3,4,5,6,7,8,9]},"xaxis4":{"anchor":"y4","domain":[0.5700000000000001,1.0],"title":{"text":"race"}},"yaxis4":{"anchor":"x4","domain":[0.0,0.375],"title":{"text":"age"},"tickvals":[2,3,4,5,6,7,8,9]},"annotations":[{"font":{"size":16},"showarrow":false,"text":"Female patients (coad_read_FS)","x":0.215,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Male patients (coad_read_FS)","x":0.785,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Female patients (coad_read_PM)","x":0.215,"xanchor":"center","xref":"paper","y":0.375,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Male patients (coad_read_PM)","x":0.785,"xanchor":"center","xref":"paper","y":0.375,"yanchor":"bottom","yref":"paper"}],"coloraxis":{"colorbar":{"x":0.43,"y":0.8,"len":0.5,"thickness":23},"colorscale":[[0.0,"rgb(47, 15, 61)"],[0.09090909090909091,"rgb(76, 21, 80)"],[0.18181818181818182,"rgb(107, 24, 93)"],[0.2727272727272727,"rgb(138, 29, 99)"],[0.36363636363636365,"rgb(168, 40, 96)"],[0.45454545454545453,"rgb(195, 56, 90)"],[0.5454545454545454,"rgb(216, 80, 83)"],[0.6363636363636364,"rgb(231, 109, 84)"],[0.7272727272727273,"rgb(240, 142, 98)"],[0.8181818181818182,"rgb(246, 173, 119)"],[0.9090909090909091,"rgb(250, 205, 145)"],[1.0,"rgb(253, 237, 176)"]]},"coloraxis2":{"colorscale":[[0.0,"rgb(39, 26, 44)"],[0.09090909090909091,"rgb(54, 43, 77)"],[0.18181818181818182,"rgb(64, 60, 115)"],[0.2727272727272727,"rgb(62, 82, 143)"],[0.36363636363636365,"rgb(62, 108, 150)"],[0.45454545454545453,"rgb(68, 130, 155)"],[0.5454545454545454,"rgb(7 ...
#
# var gd = document.getElementById('3b11e899-49ef-478b-bac8-809c3ceda4ff');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
